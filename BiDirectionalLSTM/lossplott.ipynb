# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
path = "/content/gdrive/My Drive/3_Semester_Analyse_Projekt/LSTM/EmbeddingLayer/EmbeddingBidirectionalLSTM/smallBatchSize/"

os.chdir(path)

# %%
import pandas as pd

# %%
dfloss = pd.read_csv('log.csv', sep=';')

# %%
dfloss
# Out:
#     epoch  accuracy      loss
# 0       0  0.482611  2.329436
# 1       1  0.489113  2.289903
# 2       2  0.494993  2.257953
# 3       3  0.499264  2.219327
# 4       4  0.506086  2.185948
# ..    ...       ...       ...
# 95     45  0.743172  0.956677
# 96     46  0.704991  1.119421
# 97     47  0.733718  0.990041
# 98     48  0.748185  0.931777
# 99     49  0.752820  0.914060
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# gca stands for 'get current axis'
ax = plt.gca()

dfloss.plot(kind='line',x='epoch',y='accuracy',ax=ax)
dfloss.plot(kind='line',x='epoch',y='loss', color='red', ax=ax)

plt.show()
#plt.savefig('loss-acc-plot.png')

'''
savefig(fname, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)
'''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-25318069269e> in <module>()
#       4 ax = plt.gca()
#       5
# ...
